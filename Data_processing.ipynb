# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Sample_Data.csv')

# %%
df.TimeIndex = pd.to_datetime(df.TimeIndex)

# %%
df.TimeIndex

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x25577d6d370>,
#  <matplotlib.lines.Line2D at 0x25579460110>,
#  <matplotlib.lines.Line2D at 0x255794af0e0>,
#  <matplotlib.lines.Line2D at 0x255794afef0>]

# %%
df.columns

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)
sns.lineplot(df, x='TimeIndex', y='VoltageP1', ax=ax1, errorbar=None)
sns.lineplot(df, x='TimeIndex', y='VoltageP2', ax=ax2, errorbar=None)
# Out:
# <Axes: xlabel='TimeIndex', ylabel='VoltageP2'>

# %%
plt.plot(df.TimeIndex, df.VoltageP2, )

# %%
df
# Out:
#      Unnamed: 0  VoltageP1  VoltageP2                     TimeIndex
# 0             0     0.0000     0.0000 1970-01-01 00:00:01.772664444
# 1             1   143.6900     0.7085 1970-01-01 00:00:01.772664444
# 2             2     0.4595     0.6110 1970-01-01 00:00:01.772664444
# 3             3     0.5475     0.9190 1970-01-01 00:00:01.772664444
# 4             4     0.6205    61.8035 1970-01-01 00:00:01.772664444
# ..          ...        ...        ...                           ...
# 148         148     0.0000     1.1485 1970-01-01 00:00:01.772664459
# 149         149     0.0000     0.9530 1970-01-01 00:00:01.772664459
# 150         150     0.1125     0.9530 1970-01-01 00:00:01.772664459
# 151         151   143.7290     0.8750 1970-01-01 00:00:01.772664459
# 152         152   143.2650     1.0800 1970-01-01 00:00:01.772664460
#
# [153 rows x 4 columns]
